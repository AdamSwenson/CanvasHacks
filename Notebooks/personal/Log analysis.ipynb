# %% [markdown]
# going to need to do serious reduction on db and delete old records..
#
# To calculate:
#     character / minute for each student each question
#
#     backspacing overwrtting for each question
#
#     time per question

# %%
import re
regex = re.compile( r"\bessay (?!walkthrough)\b|\bcontent assignment\b" )

# %%
assignment_name = "Essay Walkthrough"
regex.search( assignment_name.strip().lower() )

# %%
assignment_name = "Unit 8 Essay 8"
regex.search( assignment_name.strip().lower() )
